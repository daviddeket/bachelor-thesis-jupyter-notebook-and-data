# %%
from web3 import Web3
moralis = "https://speedy-nodes-nyc.moralis.io/e35926d48567958aa0c6c58b/avalanche/mainnet"

w3 = Web3(Web3.HTTPProvider(moralis))
w3.isConnected()
# Out:
# True

# %%
a = w3.eth.filter('pending')

# %%
address = "0x957Ca4a4aA7CDc866cf430bb140753F04e273bC0"
contract = w3.contract.Contract(address)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 address = "0x957Ca4a4aA7CDc866cf430bb140753F04e273bC0"
# ----> 2 contract = w3.contract.Contract(address)
#
# AttributeError: 'Web3' object has no attribute 'contract'

# %%
# get price data
# This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

def getPrice(coin):
    url = 'https://api.coingecko.com/api/v3/coins/'+str(coin)+'/market_chart?vs_currency=usd&days=30'
    headers = {
      'Accepts': 'application/json'
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url)
      data = json.loads(response.text)
      return data
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      return e

# %%
print(getPrice("avalanche-2"))
# Out:
# {'prices': [[1646557450425, 75.47378313910893], [1646560869209, 75.06404148665095], [1646564508156, 74.45599686778301], [1646568132727, 75.0510905942906], [1646571735036, 75.35215346840694], [1646575342174, 75.73615679154786], [1646578916852, 75.35497242245069], [1646582524033, 75.10773550998115], [1646586052072, 75.25266192838068], [1646589744808, 75.12779774410667], [1646593306238, 74.38297334300104], [1646596953606, 73.13650654092882], [1646600507534, 73.66456946236724], [1646604039582, 73.79560459185255], [1646607678241, 73.8668289412896], [1646611352458, 72.56544866386706], [1646614809819, 72.31053409096687], [1646618506172, 72.26730027891332], [1646622009374, 70.87732348704864], [1646625715427, 71.29769077980092], [1646629311506, 71.52071383368501], [1646632875693, 72.15258446275362], [1646636573741, 72.45237988965887], [1646640044011, 71.92078278818929], [1646643689315, 72.72762466674772], [1646647309435, 72.9885654518234], [1646650877978, 73.62219147831588], [1646654565914, 7
# ...
